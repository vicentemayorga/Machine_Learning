# %% [markdown]
# # Instrucciones:
# - Descargue el notebook y cárguelo en su Drive.
# - Todas las preguntas deben ser contestadas en su notebook.
# - Para que una pregunta esté correcta el código debe correr.
# - En la pregunta 1, si es necesario, realice comentarios breves en su código explicando lo que está realizando o sus resultados.
# - Una vez culminada su tarea, suba su notebook al buzón de tareas de Canvas.

# %% [markdown]
# #1. EDA (85%)

# %% [markdown]
# Para esta actividad se utilizará un dataset con las caraterísticas de vinos catados en diferentes tiendas de Estados Unidos en 2022. El dataset está disponible en el siguiente [Github](https://raw.githubusercontent.com/fco-olivares/AML_1.2023/main/wine_tarea1.csv).<br>
#
# Descripción del dataset:
#
# Variables:
# *   date: Fecha en la que se realizó la cata.
# *   fixed acidity, volatile acidity, citric acid, residual sugar chlorides, free sulfur dioxide, total sulfur dioxide, pH, sulphates: Características del vino catado.
# *   density: Es la densidad del vino. Suponga que 1 es la densidad del agua.
# *   wine type: Clasifica el vino según su color.
# *   alcohol: Graduación alcohólica del vino catado.
# *   quality: Calidad del vino determinada por el catador.
# *   store type: Tipo de tienda en la que se cató el vino.
# *   country: País en la que se realizó la cata.

# %% [markdown]
# 0) Importe las librerías que usará en su tarea.
#
# Esta pregunta no tiene puntaje, pero sí puede restar puntaje si importa librerías que no usa en su tarea.

# %% [markdown]
# 1) Importe el dataset como un DataFrame (df) directamente desde Github (es decir, no descargue el archivo manualmente). A lo largo de la tarea este df se denominará como "df".

# %% [markdown]
# 2) Utilice las funciones de Pandas "head", "tail", "info" y "dtype" para describir el df. Explique brevemente para qué sirve cada función.

# %% [markdown]
# 3) La variable "country" es innecesaria debido que contiene el mismo valor para todas las observaciones. Elimine esta variable de su df.

# %% [markdown]
# 4) Por alguna razón el tipo de la variable "alcohol" es determinada por Python como objeto en vez de número. Investigue el inconveniente y haga los reparos necesarios para que la variable sea del tipo numérico (float).

# %% [markdown]
# 5) Transforme el tipo de la variable "date" a datetime.
#
# Cree la variable "week day" en su df con el día de la semana en el cual se realizó la cata.

# %% [markdown]
# 6) Para determinar si las variables son "útiles" y sus valores son "correctos" es necesario comprender cada uno de los atributos del dataset.
# Investigue y explique brevemente la relación **teórica** entre el vino y cada una de las variables denominadas como "Características del vino catado" en la introducción.
#
# Ejemplo: Existe una variable denominada "antigüedad". La antigüedad es la cantidad de años que existen entre la fermentación del vino y la cata. Su relación con el vino es que, a una mayor antigüedad, el vino aumenta su intensidad aromática y disminuye su amargor.

# %% [markdown]
# Escriba su respuesta aquí...

# %% [markdown]
# 7) Calcule estadísticas descriptivas para cada variable numérica.

# %% [markdown]
# 8) Según corresponda, realice un gráfico de distribución de densidad o histograma para describir cada variable del df.
#
# ¿Por qué es importante analizar las distribuciones de las variables a utilizar en su modelo? Ejemplifique su respuesta con al menos una de las variables del df.

# %% [markdown]
# 9) El df contiene variables con missing values (NaN). Impute los NaN con el método que estime conveniente, justificando su decisión.
#
# ¿Es pertinente eliminar alguna de estas variables? Hágalo si es el caso.

# %% [markdown]
# 11) Supongamos que "pH" es su variable objetivo. Estudie la correlación de esta variable con el resto de las variables del df. ¿Por qué es importante analizar la correlación entre las variables?

# %% [markdown]
# 12) Realice tres scatterplots (una por variable) de las tres variables con la mayor correlación con la variable objetivo.
#
# Utilizando los parámetros de la función con la que hizo los scatterplots, coloque un título a cada gráfico y coloree los puntos de los scatterplots con colores diferentes.

# %% [markdown]
# 13) Elimine las observaciones outliers considerando la relación entre la variable objetivo y las tres variables seleccionadas en la pregunta anterior. Haga el mismo ejercicio para la relación de la variable objetivo con las variables categóricas. Justifique rigurosamente sus decisiones.

# %% [markdown]
# # 2. SQL (15%)
#
# Ir a https://www.sql-practice.com/ y realizar las siguientes consultas de la tabla *customers* del database *northwind.db* (escriba en este notebook sus consultas):

# %% [markdown]
# 1) Seleccionar todos los datos<br>
# 2) Selecionar las columnas customer_id, contact_title, city, country. <br>
# 3) ¿Cuántas ciudades (city) distintas hay? <br>
# 4) Seleccionar todos los customers y ordenar alfabéticamente decreciente por país (country). <br>
# 5) Seleccionar los customers que tengan como *country* a "USA", "UK" o "France". <br>
# 6) Contar los customers que tienen como *contact_tile* "Marketing Manager" <br>
# 7) Agrupar por *contact_tile*, contar la cantidad de customers por *contact_tile* y renombrar esta columna como "cantidad_customers" <br>
